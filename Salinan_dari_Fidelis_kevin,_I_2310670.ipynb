# %% [markdown]
# <a href="https://colab.research.google.com/github/fidelkeren/uas-fidel/blob/main/Salinan_dari_Fidelis_kevin%2C_I_2310670.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# %%
import sys
print("Python version: {}".format(sys.version))
# Out:
# Python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
import pandas as pd

data = {"Nama":["Fidel", "ujo", "rara"],
        "Umur":["21", "37", "38"],
        "Kota":["bogor", "Jawa", "papua"]}
data_2 = pd.DataFrame(data)
print(data_2)
# Out:
#     Nama Umur   Kota
# 0  Fidel   21  bogor
# 1    ujo   37   Jawa
# 2   rara   38  papua

# %%
data_2["Umur"] = pd.to_numeric(data_2["Umur"])
display(data_2[data_2.Umur >= 30])
# Out:
#    Nama  Umur   Kota
# 1   ujo    37   Jawa
# 2  rara    38  papua

# %%
display(data_2[data_2.umur < 30])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4267738054.py in <cell line: 0>()
# ----> 1 display(data_2[data_2.umur <30])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'umur'

# %%
display(data_2[data_2.Nama == "Fidel"])
# Out:
#     Nama  Umur   Kota
# 0  Fidel    21  bogor

# %%
display(data_2[(data_2.Nama == "Fidel") | (data_2.Nama == "rara")])
# Out:
#     Nama  Umur   Kota
# 0  Fidel    21  bogor
# 2   rara    38  papua

# %%
display(data_2[data_2.Nama != "rara"])
# Out:
#     Nama  Umur   Kota
# 0  Fidel    21  bogor
# 1    ujo    37   Jawa

# %%
import numpy as np
a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
import matplotlib.pyplot as plt
x = np.linspace(-10,10,100)
y = np.tan(x)

plt.plot(x,y, label = "Grafik Tan")
plt.legend()

# %%
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...
